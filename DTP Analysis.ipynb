# %%
import pandas as pd, math
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
file = "/Users/John/Documents/Projects/Source Data Files/VizForSocialGood/Dear Tech People/dtp_data.csv"
df = pd.read_csv(filepath_or_buffer=file,delimiter=',')
df.dtypes
# Out:
# date_pulled                  object
# company_name                 object
# sector_1                     object
# sector_2                     object
# customer_base_1              object
# customer_base_2              object
# hq_location                  object
# sf_based                     object
# overall_ranking               int64
# leadership_ranking            int64
# technical_ranking             int64
# total_employees              object
# total_male                   object
# overall_male_white           object
# overall_male_asian            int64
# overall_male_black            int64
# overall_male_latinx           int64
# overall_male_other           object
# total_female                 object
# overall_female_white         object
# overall_female_asian          int64
# overall_female_black          int64
# overall_female_latinx         int64
# overall_female_other         object
# total_technical             float64
# technical_male_white        float64
# ...

# %%
a = df[['company_name','overall_male_other','overall_female_other']]

# %%
b = a[a['overall_male_other'] == 0]
b
# Out:
# Empty DataFrame
# Columns: [company_name, overall_male_other, overall_female_other]
# Index: []

# %%
g_data = data.groupby('sector_1').count()
g_data.sort_values(by='company_name',ascending=False)\
    .plot(kind='bar',title='# of Companies by Primary Sector', color='green',legend =False)

# %%
data2 = df[['company_name','sf_based']]

# %%
data2 = data2.fillna('False')

# %%
data2
# Out:
#             company_name sf_based
# 0         *American Pop.    False
# 1                *Google    False
# 2                23andMe    False
# 3                 Affirm     True
# 4                 Airbnb     True
# 5            AppDynamics     True
# 6        Aryaka Networks    False
# 7                  Blend     True
# 8             Blue Apron    False
# 9     Blue Jeans Network    False
# 10                   Box    False
# 11                Buffer     True
# 12              BuzzFeed    False
# 13                Casper    False
# 14               Chariot     True
# 15                Checkr     True
# 16                Clever     True
# 17         Clover Health     True
# 18              Cohesity    False
# 19              Coinbase     True
# 20     Collective Health     True
# 21          Credit Karma     True
# 22     Cruise Automation     True
# 23            CultureAmp    False
# 24            Cybereason    False
# 25               Cylance    False
# ...

# %%
pd2 = data2.groupby(by='sf_based').count()
pd2
# Out:
#           company_name
# sf_based
# True                50
# False               52

# %%
labels = pd2.index
sizes = pd2['company_name']
plt.title = 'Based in the Bay Area'

plt.pie(sizes, 
        labels=labels, 
        shadow=False, 
        explode=(0,0.02),
        startangle=90,
        autopct='%1.1f%%'
)

plt.axis('equal')
plt.tight_layout
# Out:
# <function matplotlib.pyplot.tight_layout>
