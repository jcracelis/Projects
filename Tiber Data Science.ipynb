# %%
# imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# this allows plots to appear directly in the notebook
# %matplotlib inline

# %%
# read data into a DataFrame
data = pd.read_csv('https://community.watsonanalytics.com/wp-content/uploads/2015/03/WA_Fn-UseC_-Telco-Customer-Churn.csv',index_col=0)
data.head()
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
# 3668-QPYBK    Male              0      No         No       2          Yes
# 7795-CFOCW    Male              0      No         No      45           No
# 9237-HQITU  Female              0      No         No       2          Yes
#
#                MultipleLines InternetService OnlineSecurity OnlineBackup  \
# customerID
# 7590-VHVEG  No phone service             DSL             No          Yes
# 5575-GNVDE                No             DSL            Yes           No
# 3668-QPYBK                No             DSL            Yes          Yes
# 7795-CFOCW  No phone service             DSL            Yes           No
# 9237-HQITU                No     Fiber optic             No           No
#
# ...

# %%
# print the shape of the DataFrame
data.shape
# Out:
# (7043, 20)

# %%
data.describe
# Out:
# <bound method NDFrame.describe of             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
# 3668-QPYBK    Male              0      No         No       2          Yes
# 7795-CFOCW    Male              0      No         No      45           No
# 9237-HQITU  Female              0      No         No       2          Yes
# 9305-CDSKC  Female              0      No         No       8          Yes
# 1452-KIOVK    Male              0      No        Yes      22          Yes
# 6713-OKOMC  Female              0      No         No      10           No
# 7892-POOKP  Female              0     Yes         No      28          Yes
# 6388-TABGU    Male              0      No        Yes      62          Yes
# 9763-GRSKD    Male              0     Yes        Yes      13          Yes
# ...

# %%
data.index
# Out:
# Index(['7590-VHVEG', '5575-GNVDE', '3668-QPYBK', '7795-CFOCW', '9237-HQITU',
#        '9305-CDSKC', '1452-KIOVK', '6713-OKOMC', '7892-POOKP', '6388-TABGU',
#        ...
#        '9767-FFLEM', '0639-TSIQW', '8456-QDAVC', '7750-EYXWZ', '2569-WGERO',
#        '6840-RESVB', '2234-XADUH', '4801-JZAZL', '8361-LTMKD', '3186-AJIEK'],
#       dtype='object', name='customerID', length=7043)

# %%
data.loc['6713-OKOMC']
# Out:
# gender                        Female
# SeniorCitizen                      0
# Partner                           No
# Dependents                        No
# tenure                            10
# PhoneService                      No
# MultipleLines       No phone service
# InternetService                  DSL
# OnlineSecurity                   Yes
# OnlineBackup                      No
# DeviceProtection                  No
# TechSupport                       No
# StreamingTV                       No
# StreamingMovies                   No
# Contract              Month-to-month
# PaperlessBilling                  No
# PaymentMethod           Mailed check
# MonthlyCharges                 29.75
# TotalCharges                   301.9
# Churn                             No
# Name: 6713-OKOMC, dtype: object

# %% [markdown]
# # Get the Unique values for all the columns

# %%
col = data.columns

# %%
i=0
for x in col:
    i = i+1
    print('data.'+x+'.unique()' )
# Out:
# data.gender.unique()
# data.SeniorCitizen.unique()
# data.Partner.unique()
# data.Dependents.unique()
# data.tenure.unique()
# data.PhoneService.unique()
# data.MultipleLines.unique()
# data.InternetService.unique()
# data.OnlineSecurity.unique()
# data.OnlineBackup.unique()
# data.DeviceProtection.unique()
# data.TechSupport.unique()
# data.StreamingTV.unique()
# data.StreamingMovies.unique()
# data.Contract.unique()
# data.PaperlessBilling.unique()
# data.PaymentMethod.unique()
# data.MonthlyCharges.unique()
# data.TotalCharges.unique()
# data.Churn.unique()

# %% [markdown]
# # Combine Filtered Elements

# %%
is_secure = data['OnlineSecurity'] != 'Yes' 
no_dependents = data['Dependents'] == 'No' 
data[is_secure & no_dependents]
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 9237-HQITU  Female              0      No         No       2          Yes
# 9305-CDSKC  Female              0      No         No       8          Yes
# 7892-POOKP  Female              0     Yes         No      28          Yes
# 7469-LKBCI    Male              0      No         No      16          Yes
# 8091-TTVAX    Male              0     Yes         No      58          Yes
# 0280-XJGEX    Male              0      No         No      49          Yes
# 8191-XWSZG  Female              0      No         No      52          Yes
# 4183-MYFRB  Female              0      No         No      21          Yes
# 8779-QRDMV    Male              1      No         No       1           No
# 1680-VDCWW    Male              0     Yes         No      12          Yes
# ...
