# %%
import requests
from bs4 import BeautifulSoup

# %%
r = requests.get('https://www.facebook.com/john.racelis.3')

# %%
r.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en" id="facebook" class="no_js">\n<head><meta charset="utf-8" /><meta name="referrer" content="default" id="meta_referrer" /><script>window._cstart=+new Date();</script><script>function envFlush(a){function b(b){for(var c in a)b[c]=a[c]}window.requireLazy?window.requireLazy(["Env"],b):(window.Env=window.Env||{},b(window.Env))}envFlush({"ajaxpipe_token":"AXjAzizLonxcyK1K","timeslice_heartbeat_config":{"pollIntervalMs":33,"idleGapThresholdMs":60,"ignoredTimesliceNames":{"requestAnimationFrame":true,"Event listenHandler mousemove":true,"Event listenHandler mouseover":true,"Event listenHandler mouseout":true,"Event listenHandler scroll":true},"isHeartbeatEnabled":true,"isArtilleryOn":false},"shouldLogCounters":true,"timeslice_categories":{"react_render":true,"reflow":true},"sample_continuation_stacktraces":true,"dom_mutation_flag":true,"stack_trace_limit":30,"timesliceBufferSize":5000});</script><style></style><script>__DEV__=0;CavalryLogger=window.CavalryL
# ...

# %%
import facebook
import requests

# %%
access_token = 'EAACEdEose0cBADJtytss7ZCXAvFZA5IJo30FZCjca5sZBgPKgFMDYgw9ZACP5kvZBZABkjI624xef5Xsa6kMs8KTMH3FLgZBgtA35Pyu5wMM9CG37sboLiD5MfiA37cixvkZBQZCAXDlO6KjqndlNyYAu7Cf4qIzSZAeg1ng2z9efR1EdrurZBvIub3ZCYwziIFHZCy1wZD'

graph = facebook.GraphAPI(access_token,version='3.0')
profile = graph.get_object(id='me')

# %%
profile

# %%
posts=graph.get_connections(profile['id'],'posts')
posts

# %%
msg=graph.get_connections(profile['id'],'message')
msg
